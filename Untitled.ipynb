# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open('./images/justice.jpeg')

plt.imshow(img)
plt.show()

# binary > 0과 1로표현
# gray scale > 0~255
# color image > (0~255,0~255,0~255) RGB

# color image > gray scale
# 1. (RGB 평균, RGB 평균, RGB 평균)
# 2. (RGB 평균)

# PNG = (R,G,B Alpha) 
# Alpha 는 투명도 이미지를 더 다양하게 표현 가능
